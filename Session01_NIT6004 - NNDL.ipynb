# %% [markdown]
# #Session 01 - NIT 6004 - Neural Network and Deep Learning

# %%
print("Session 01 - NIT 6004 - Neural Network and Deep Learning")
# Out:
# Session 01 - NIT 6004 - Neural Network and Deep Learning

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0
